# %%
import numpy as np
from model.helper import calculate_metrics
from sklearn.linear_model import LogisticRegression
from data.preprocess import load_from_file
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
name_format = "fcv-%s"

data = []
for i in range(10):
    data.append(load_from_file(name_format % i))

# %%
def evaluate(pred_scores, target):
    pred = np.argmax(pred_scores, axis=1)
    print(pred.shape)
    precision, recall, f1, accuracy = calculate_metrics(target, pred, classificationReport=True, num_classes=3)
    return precision ,recall, f1

# %%
def lr_with_freq(data):
    text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(2,5), analyzer="char")),
                    ('tfidf', TfidfTransformer()),
                    ('clf', LogisticRegression(multi_class="multinomial", solver="lbfgs"))])    
    text_clf.fit(data["x_train"], data["y_train"])
    print("train")
    evaluate(text_clf.predict_proba(data["x_train"]), data["y_train"])
    print("test")
    evaluate(text_clf.predict_proba(data["x_test"]), data["y_test"])
    
    return text_clf

# %% [markdown]
# ## Char-ngram Logistic Regression

# %%
for i in range(10):
    print("\n**cv-%s**" % i)
    lr_with_freq(data[i])
# Out:
# **cv-0**
# train
# (16515,)
#              precision    recall  f1-score   support
#
#        none     0.8740    0.9742    0.9214     11185
#      racism     0.9075    0.7253    0.8062      1853
#      sexism     0.9303    0.6868    0.7902      3477
#
# avg / total     0.8896    0.8857    0.8808     16515
#
# test
# (1836,)
#              precision    recall  f1-score   support
#
#        none     0.8357    0.9453    0.8871      1243
#      racism     0.8151    0.5777    0.6761       206
#      sexism     0.8380    0.6150    0.7094       387
#
# avg / total     0.8339    0.8344    0.8260      1836
#
#
# **cv-1**
# train
# (16515,)
#              precision    recall  f1-score   support
#
#        none     0.8757    0.9750    0.9227     11185
#      racism     0.9076    0.7264    0.8070      1853
#      sexism     0.9325    0.6917    0.7943      3477
#
# avg / total     0.8912    0.8874    0.8826     16515
#
# test
# (1836,)
#              precision    recall  f1-score   support
#
#        none     0.8266    0.9397    0.8795      1243
#      racism     0.8250    0.6408    0.7213       206
#      sexism     0.8099    0.5504    0.6554       387
#
# avg / total     0.8229    0.8241    0.8145      1836
#
#
# **cv-2**
# train
# (16515,)
#              precision    recall  f1-score   support
#
#        none     0.8754    0.9745    0.9223     11185
#      racism     0.9077    0.7221    0.8043      1853
#      sexism     0.9305    0.6928    0.7943      3477
#
# avg / total     0.8906    0.8869    0.8821     16515
#
# test
# (1836,)
#              precision    recall  f1-score   support
#
#        none     0.8180    0.9509    0.8795      1243
#      racism     0.8322    0.5777    0.6819       206
#      sexism     0.8427    0.5401    0.6583       387
#
# avg / total     0.8248    0.8224    0.8107      1836
#
#
# **cv-3**
# train
# (16515,)
#              precision    recall  f1-score   support
#
#        none     0.8753    0.9750    0.9224     11185
#      racism     0.9080    0.7242    0.8058      1853
#      sexism     0.9321    0.6911    0.7937      3477
#
# avg / total     0.8909    0.8871    0.8822     16515
#
# test
# (1836,)
#              precision    recall  f1-score   support
#
#        none     0.8241    0.9421    0.8791      1243
#      racism     0.8012    0.6262    0.7030       206
#      sexism     0.8268    0.5426    0.6552       387
#
# avg / total     0.8221    0.8224    0.8122      1836
#
#
# **cv-4**
# train
# (16516,)
#              precision    recall  f1-score   support
#
#        none     0.8742    0.9752    0.9219     11185
#      racism     0.9126    0.7269    0.8093      1853
#      sexism     0.9309    0.6857    0.7897      3478
#
# avg / total     0.8904    0.8864    0.8815     16516
#
# test
# (1835,)
#              precision    recall  f1-score   support
#
#        none     0.8231    0.9469    0.8807      1243
#      racism     0.7468    0.5583    0.6389       206
#      sexism     0.8845    0.5751    0.6970       386
#
# avg / total     0.8274    0.8251    0.8149      1835
#
#
# **cv-5**
# train
# (16516,)
#              precision    recall  f1-score   support
#
#        none     0.8744    0.9750    0.9220     11185
#      racism     0.9092    0.7237    0.8059      1853
#      sexism     0.9319    0.6886    0.7920      3478
#
# avg / total     0.8904    0.8865    0.8816     16516
#
# test
# (1835,)
#              precision    recall  f1-score   support
#
#        none     0.8325    0.9316    0.8793      1243
#      racism     0.7586    0.6408    0.6947       206
#      sexism     0.8185    0.5725    0.6738       386
#
# avg / total     0.8213    0.8234    0.8153      1835
#
#
# **cv-6**
# train
# (16516,)
#              precision    recall  f1-score   support
#
#        none     0.8741    0.9747    0.9217     11185
#      racism     0.9103    0.7232    0.8060      1853
#      sexism     0.9304    0.6880    0.7911      3478
#
# avg / total     0.8900    0.8861    0.8812     16516
#
# test
# (1835,)
#              precision    recall  f1-score   support
#
#        none     0.8201    0.9501    0.8804      1243
#      racism     0.7961    0.5874    0.6760       206
#      sexism     0.8560    0.5389    0.6614       386
#
# avg / total     0.8250    0.8229    0.8113      1835
#
#
# **cv-7**
# train
# (16516,)
#              precision    recall  f1-score   support
#
#        none     0.8742    0.9753    0.9220     11185
#      racism     0.9074    0.7194    0.8025      1853
#      sexism     0.9342    0.6898    0.7936      3478
#
# avg / total     0.8906    0.8865    0.8815     16516
#
# test
# (1835,)
#              precision    recall  f1-score   support
#
#        none     0.8250    0.9517    0.8838      1243
#      racism     0.8741    0.6068    0.7163       206
#      sexism     0.8178    0.5466    0.6553       386
#
# avg / total     0.8290    0.8278    0.8169      1835
#
#
# **cv-8**
# train
# (16517,)
#              precision    recall  f1-score   support
#
#        none     0.8744    0.9741    0.9216     11186
#      racism     0.9097    0.7285    0.8091      1853
#      sexism     0.9296    0.6875    0.7904      3478
#
# avg / total     0.8900    0.8862    0.8813     16517
#
# test
# (1834,)
#              precision    recall  f1-score   support
#
#        none     0.8157    0.9477    0.8767      1242
#      racism     0.8261    0.5534    0.6628       206
#      sexism     0.8142    0.5337    0.6448       386
#
# avg / total     0.8165    0.8162    0.8039      1834
#
#
# **cv-9**
# train
# (16518,)
#              precision    recall  f1-score   support
#
#        none     0.8745    0.9745    0.9218     11186
#      racism     0.9080    0.7190    0.8025      1854
#      sexism     0.9296    0.6909    0.7927      3478
#
# avg / total     0.8899    0.8861    0.8812     16518
#
# test
# (1833,)
#              precision    recall  f1-score   support
#
#        none     0.8233    0.9493    0.8818      1242
#      racism     0.8267    0.6049    0.6986       205
#      sexism     0.8406    0.5466    0.6625       386
#
# avg / total     0.8273    0.8260    0.8151      1833

# %% [markdown]
# ### SVM

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC

# %%
def svm(data):
    text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(2,5), analyzer="char")),
                    ('tfidf', TfidfTransformer()),
                    ('clf', SGDClassifier(loss='log', penalty='l2'))])    
    text_clf.fit(data["x_train"], data["y_train"])
    print("train")
    evaluate(text_clf.predict_proba(data["x_train"]), data["y_train"])
    print("test")
    evaluate(text_clf.predict_proba(data["x_test"]), data["y_test"])
    
    return text_clf

# %%
for i in range(10):
    print("\n**cv-%s**" % i)
    svm(data[i])
# Out:
# **cv-0**
# train
# (16515,)
#              precision    recall  f1-score   support
#
#        none     0.8167    0.9705    0.8870     11185
#      racism     0.8689    0.5936    0.7054      1853
#      sexism     0.9055    0.5096    0.6522      3477
#
# avg / total     0.8412    0.8312    0.8172     16515
#
# test
# (1836,)
#              precision    recall  f1-score   support
#
#        none     0.8061    0.9630    0.8776      1243
#      racism     0.8306    0.5000    0.6242       206
#      sexism     0.8811    0.5168    0.6515       387
#
# avg / total     0.8246    0.8170    0.8015      1836
#
#
# **cv-1**
# train
# (16515,)
#              precision    recall  f1-score   support
#
#        none     0.8196    0.9709    0.8889     11185
#      racism     0.8722    0.5931    0.7061      1853
#      sexism     0.9082    0.5234    0.6641      3477
#
# avg / total     0.8441    0.8343    0.8210     16515
#
# test
# (1836,)
#              precision    recall  f1-score   support
#
#        none     0.8027    0.9461    0.8685      1243
#      racism     0.8235    0.5437    0.6550       206
#      sexism     0.8085    0.4910    0.6109       387
#
# avg / total     0.8063    0.8050    0.7903      1836
#
#
# **cv-2**
# train
# (16515,)
#              precision    recall  f1-score   support
#
#        none     0.8202    0.9692    0.8885     11185
#      racism     0.8706    0.5920    0.7048      1853
#      sexism     0.8989    0.5269    0.6644      3477
#
# avg / total     0.8424    0.8337    0.8207     16515
#
# test
# (1836,)
#              precision    recall  f1-score   support
#
#        none     0.7984    0.9590    0.8713      1243
#      racism     0.8268    0.5097    0.6306       206
#      sexism     0.8565    0.4780    0.6136       387
#
# avg / total     0.8138    0.8072    0.7900      1836
#
#
# **cv-3**
# train
# (16515,)
#              precision    recall  f1-score   support
#
#        none     0.8187    0.9714    0.8885     11185
#      racism     0.8729    0.5969    0.7090      1853
#      sexism     0.9095    0.5171    0.6593      3477
#
# avg / total     0.8439    0.8337    0.8201     16515
#
# test
# (1836,)
#              precision    recall  f1-score   support
#
#        none     0.8035    0.9509    0.8710      1243
#      racism     0.8125    0.5680    0.6686       206
#      sexism     0.8326    0.4755    0.6053       387
#
# avg / total     0.8107    0.8077    0.7923      1836
#
#
# **cv-4**
# train
# (16516,)
#              precision    recall  f1-score   support
#
#        none     0.8184    0.9697    0.8877     11185
#      racism     0.8719    0.6098    0.7177      1853
#      sexism     0.9019    0.5104    0.6519      3478
#
# avg / total     0.8420    0.8326    0.8189     16516
#
# test
# (1835,)
#              precision    recall  f1-score   support
#
#        none     0.8045    0.9566    0.8739      1243
#      racism     0.7343    0.5097    0.6017       206
#      sexism     0.9159    0.5078    0.6533       386
#
# avg / total     0.8200    0.8120    0.7970      1835
#
#
# **cv-5**
# train
# (16516,)
#              precision    recall  f1-score   support
#
#        none     0.8209    0.9698    0.8891     11185
#      racism     0.8724    0.6050    0.7145      1853
#      sexism     0.9028    0.5236    0.6628      3478
#
# avg / total     0.8439    0.8349    0.8219     16516
#
# test
# (1835,)
#              precision    recall  f1-score   support
#
#        none     0.8040    0.9372    0.8655      1243
#      racism     0.7532    0.5631    0.6444       206
#      sexism     0.8147    0.4896    0.6117       386
#
# avg / total     0.8005    0.8011    0.7873      1835
#
#
# **cv-6**
# train
# (16516,)
#              precision    recall  f1-score   support
#
#        none     0.8191    0.9707    0.8885     11185
#      racism     0.8729    0.5931    0.7063      1853
#      sexism     0.9051    0.5210    0.6613      3478
#
# avg / total     0.8432    0.8336    0.8202     16516
#
# test
# (1835,)
#              precision    recall  f1-score   support
#
#        none     0.7997    0.9606    0.8728      1243
#      racism     0.8074    0.5291    0.6393       206
#      sexism     0.8744    0.4689    0.6105       386
#
# avg / total     0.8163    0.8087    0.7914      1835
#
#
# **cv-7**
# train
# (16516,)
#              precision    recall  f1-score   support
#
#        none     0.8182    0.9709    0.8880     11185
#      racism     0.8685    0.5915    0.7037      1853
#      sexism     0.9087    0.5178    0.6597      3478
#
# avg / total     0.8429    0.8329    0.8193     16516
#
# test
# (1835,)
#              precision    recall  f1-score   support
#
#        none     0.8036    0.9614    0.8755      1243
#      racism     0.8846    0.5583    0.6845       206
#      sexism     0.8349    0.4715    0.6026       386
#
# avg / total     0.8193    0.8131    0.7966      1835
#
#
# **cv-8**
# train
# (16517,)
#              precision    recall  f1-score   support
#
#        none     0.8228    0.9686    0.8898     11186
#      racism     0.8723    0.6044    0.7141      1853
#      sexism     0.8997    0.5339    0.6702      3478
#
# avg / total     0.8445    0.8362    0.8238     16517
#
# test
# (1834,)
#              precision    recall  f1-score   support
#
#        none     0.7935    0.9589    0.8684      1242
#      racism     0.8220    0.4709    0.5988       206
#      sexism     0.8326    0.4637    0.5957       386
#
# avg / total     0.8049    0.7999    0.7807      1834
#
#
# **cv-9**
# train
# (16518,)
#              precision    recall  f1-score   support
#
#        none     0.8199    0.9695    0.8884     11186
#      racism     0.8691    0.5944    0.7060      1854
#      sexism     0.9016    0.5242    0.6629      3478
#
# avg / total     0.8426    0.8336    0.8205     16518
#
# test
# (1833,)
#              precision    recall  f1-score   support
#
#        none     0.8013    0.9614    0.8741      1242
#      racism     0.8582    0.5610    0.6785       205
#      sexism     0.8565    0.4637    0.6017       386
#
# avg / total     0.8193    0.8118    0.7948      1833
