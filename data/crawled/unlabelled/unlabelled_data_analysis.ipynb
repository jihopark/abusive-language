# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('./data/crawled/sexism_tweets.txt',
                     sep="\t",
                     header=None,
                     skiprows=[0],
                     names=["Tweet_ID", "Text", "Previous"],
                     error_bad_lines=False)

# %%
df.describe(include="all")
# Out:
#        Tweet_ID        Text      Previous
# count   13739    13311       1.190500e+04
# unique  13000    11895      NaN
# top     #MKR     2322065402 NaN
# freq    84       38         NaN
# mean    NaN      NaN         1.111904e+17
# std     NaN      NaN         2.761115e+17
# min     NaN      NaN         1.090400e+04
# 25%     NaN      NaN         9.072208e+07
# 50%     NaN      NaN         4.664869e+08
# 75%     NaN      NaN         2.887851e+09
# max     NaN      NaN         8.466432e+17

# %%
df.sample(n=100)
# Out:
#                                                           Tweet_ID  \
# 7068   844475176284700673
# 12082  843742444902526976
# 4705   845916903767924736
# 6972   844476322168487936
# 9017   844113400842014720
# 6393   844483039237357568
# 5547   844817097813196801
# 426    How would you taste the food smothered in all those spices?
# 1509   846304630866767872
# 10849  843759264761958400
# 9083   844111687242285056
# 9257   843478723387179008
# 3438   846279985748885505
# 12453  843391301617963008
# 2613   846290327468048384
# 6892   844476823027138561
# 7502   844469025316847616
# 2590   846291153586569216
# 286    844159932060651521
# 10321  843250982062579712
# 3716   845943307708510208
# 1541   846352876859523072
# 7583   844468637641596928
# 100    846515450364284929
# 11052  843755909801164800
# 2150   846295546151108608
# 2701   846289585286004736
# 10701  843197654460973058
# 7552   844469277109489666
# 10700  843762442609995776
# ...                   ...
# ...

# %%
df2 = pd.read_csv('./data/crawled/racism_tweets.txt',
                     sep="\t",
                     header=None,
                     skiprows=[0],
                     names=["Tweet_ID", "Text", "Previous"],
                     error_bad_lines=False)

# %%
df2.describe(include="all")
# Out:
#                   Tweet_ID                                               Text  \
# count   2189                1943
# unique  1670                1339
# top     #IslamIsTheProblem  nigger #quizzaciously #nigger #hangamuslimtonight
# freq    34                  14
# mean    NaN                 NaN
# std     NaN                 NaN
# min     NaN                 NaN
# 25%     NaN                 NaN
# 50%     NaN                 NaN
# 75%     NaN                 NaN
# max     NaN                 NaN
#
#             Previous
# count   1.473000e+03
# unique NaN
# top    NaN
# freq   NaN
# mean    3.622628e+17
# std     3.934106e+17
# min     3.297241e+06
# 25%     6.352045e+08
# 50%     3.927573e+09
# 75%     7.747524e+17
# max     8.454298e+17

# %%
df2.sample(n=100)
# Out:
#                                                                                                                            Tweet_ID  \
# 1952  844698304390709248
# 328   843225520204521472
# 395   844553348774793216
# 2146  844253149569470466
# 1998  844607448040202240
# 1287  844579179018555392
# 190   844887275099979776
# 549   #wakeup
# 12    846411868704944128
# 209   845100413691088896
# 1844  844948636429680642
# 321   843362022335135746
# 1119  845283810560364546
# 700   846600566365024256
# 651   846582545697398785
# 756   845215638289338368
# 1484  845049506001539074
# 1383  #BanIslam
# 1846  #IslamIsTheProblem. ... always.
# 2096  844586214225268736
# 972   #nosharia
# 2028  844626688336171009
# 1822  #IslamIsTheProblem
# 1045  844692741279789056
# 219   844757842619908096
# 105   846527571865092096
# 473   844433715245842433
# 380   843181327222423552
# 1083  844077538976579584
# 2095  844194510976548865
# ...                  ...
# 154   845536787753660417
# ...

# %%
df4 = pd.read_csv('./data/crawled/youtube1.csv',
                     sep="\t",
                     skiprows=[0],
                     names=["ID", "Text"],
                     error_bad_lines=False)

# %%
df4.describe(include="all")
# Out:
#                                        ID        Text
# count   12115                              12113
# unique  12115                              11747
# top     z13vdv1iamems1jvh23iiryiooqlszie5  fuck trump
# freq    1                                  27

# %%
df5 = pd.read_csv('./data/crawled/youtube2.csv',
                     sep="\t",
                     skiprows=[0],
                     names=["ID", "Text"],
                     error_bad_lines=False)

# %%
df5.describe(include="all")
# Out:
#                                        ID        Text
# count   12469                              12468
# unique  12469                              12300
# top     z13pdllwkvfax5rle222ybkyzlmghtess  Trump 2016
# freq    1                                  11

# %%
df6 = pd.read_csv('./data/crawled/youtube3.csv',
                     sep="\t",
                     skiprows=[0],
                     names=["ID", "Text"],
                     error_bad_lines=False)

# %%
df6.describe(include="all")
# Out:
#                                          ID  Text
# count   2490                                 2490
# unique  2490                                 2467
# top     z13ewrjbvmr0trobj04ch12wbrafhxfgr2k  good
# freq    1                                    3
