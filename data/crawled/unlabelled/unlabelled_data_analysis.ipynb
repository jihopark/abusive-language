# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('./sexism_tweets.tsv',
                     sep="\t",
                     header=None,
                     skiprows=[0],
                     names=["Tweet_ID", "Text", "Previous"],
                     error_bad_lines=False)

# %%
df.describe(include="all")
# Out:
#        Tweet_ID        Text      Previous
# count   13739    13311       1.190500e+04
# unique  13000    11895      NaN
# top     #MKR     2322065402 NaN
# freq    84       38         NaN
# mean    NaN      NaN         1.111904e+17
# std     NaN      NaN         2.761115e+17
# min     NaN      NaN         1.090400e+04
# 25%     NaN      NaN         9.072208e+07
# 50%     NaN      NaN         4.664869e+08
# 75%     NaN      NaN         2.887851e+09
# max     NaN      NaN         8.466432e+17

# %%
df.sample(n=100)
# Out:
#                                                                                             Tweet_ID  \
# 1842   846299910139887617
# 3394   846281113861480448
# 1165   843246414146674688
# 4829   845185716325773314
# 8992   844114001470484480
# 1976   846298414664970240
# 2318   846295432070283264
# 3757   845931843471884288
# 5271   845909157471408128
# 7117   844475557811146752
# 819    845360341487943680
# 4698   845200353750650881
# 4776   845914389723070464
# 2832   846286493509332992
# 13342  843377832243871748
# 7756   843936859642351616
# 7245    #mkr #9planetearth #tblau
# 5909   844488821433483264
# 5907   844488845890502656
# 3124   846284935749025792
# 11303  843752282109833218
# 8022   843852458271162373
# 5897   844488725761409024
# 4529   Your logic states you're #Gamergate
# 7073   844475537129037824
# 4954   845913310776123392
# 12779  843385770836545538
# 10045  844024869842952192
# 8071   844125813343625216
# 4050   845927024443080704
# ...                   ...
# ...

# %%
df2 = pd.read_csv('./racism_tweets.tsv',
                     sep="\t",
                     header=None,
                     skiprows=[0],
                     names=["Tweet_ID", "Text", "Previous"],
                     error_bad_lines=False)

# %%
df2.describe(include="all")
# Out:
#                   Tweet_ID       Text      Previous
# count   2189                1943       1.473000e+03
# unique  1670                1339      NaN
# top     #IslamIsTheProblem  186784201 NaN
# freq    34                  14        NaN
# mean    NaN                 NaN        3.622628e+17
# std     NaN                 NaN        3.934106e+17
# min     NaN                 NaN        3.297241e+06
# 25%     NaN                 NaN        6.352045e+08
# 50%     NaN                 NaN        3.927573e+09
# 75%     NaN                 NaN        7.747524e+17
# max     NaN                 NaN        8.454298e+17

# %%
df2.sample(n=100)
# Out:
#                                                                                                     Tweet_ID  \
# 1660  844161500961013761
# 128   846200236599062533
# 551   846211191483633664
# 1878  844866576188825600
# 638   #BanSharia &amp; let Trump's BEAUTIFUL DOOR allow ESCAPE from Islam after XTREME VETTING!
# 478   844386070498283525
# 495   846195849533186048
# 1809  845067295432962049
# 611   844826444123430916
# 1247  845724151197380610
# 1453  844975464779198464
# 668   Nope. No #WhiteGenocide. Crazy talk.
# 947   846112216365461504
# 1130  843848202705100800
# 1839  #FreeSpeechBitches #islamistheproblem #LondonAttack #Antwerp
# 1798  845193713991147520
# 661   846584391417692160
# 1508  #STOPIslam
# 1865  #IslamIsTheProblem✊🏿
# 1884  844973489270521856
# 119   846190283477934080
# 1653  #NoRefugees.
# 1209  845758305154797568
# 1452  #AllahIsShit &lt;&lt;&lt;&lt; 💩
# 2135  844195644143210497
# 300   843825548673470466
# 222   Gays...Electrocuted
# ...

# %%
df4 = pd.read_csv('./youtube1.csv',
                     sep="\t",
                     skiprows=[0],
                     names=["ID", "Text"],
                     error_bad_lines=False)

# %%
df4.describe(include="all")
# Out:
#                                            ID        Text
# count   12115                                  12113
# unique  12115                                  11747
# top     z12ac1xhpyyki3fr004chxxyovamxd4o5u40k  fuck trump
# freq    1                                      27

# %%
df5 = pd.read_csv('./youtube2.csv',
                     sep="\t",
                     skiprows=[0],
                     names=["ID", "Text"],
                     error_bad_lines=False)

# %%
df5.describe(include="all")
# Out:
#                                          ID        Text
# count   12469                                12468
# unique  12469                                12300
# top     z12zhr3ppzmgh50wl04cjdxz3p3rx5qjkjs  Trump 2016
# freq    1                                    11

# %%
df6 = pd.read_csv('./youtube3.csv',
                     sep="\t",
                     skiprows=[0],
                     names=["ID", "Text"],
                     error_bad_lines=False)

# %%
df6.describe(include="all")
# Out:
#                                        ID  Text
# count   2490                               2490
# unique  2490                               2467
# top     z135gjxhapyxix0mg23schsosxikgnqce  good
# freq    1                                  3
